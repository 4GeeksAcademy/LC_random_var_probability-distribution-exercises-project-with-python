# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

#1)  Calculate the first four moments:
mean, var, skew, kurt = norm.stats(moments='mvsk')   # m para media, v para varianza, s para sesgo, y k para curtosis

#2) Probability density function.
def calculate_density(x, mean=0, std=1): 
    return norm.pdf(x, loc=mean, scale=std)

#3)Log of the probability density function.
def calculate_log_density(x, mean=0, std=1): 
    return norm.logpdf(x, loc=mean, scale=std)       

#4)Random variates.
def generate_random_normal(mean=0, std=1, size=1): 
    return norm.rvs(loc=mean, scale=std, size=size, random_state=None)   

#5)Cumulative distribution function.
def cumulative_dist(x, mean=0, std=1):
    return norm.cdf(x, loc=mean, scale=std)  

#6)Percent point function (inverse of cdf — percentiles).
def percent_norm(q, mean=0, std=1):
    return norm.ppf(q, loc=mean, scale=std)

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np


np.random.seed(42)

mean=0 
std=1 
size=1
x = np.arange(-6, 6, 0.15)
q = x

pdf = calculate_density(x, mean, std)
logpdf = calculate_log_density(x, mean, std)
rvs = generate_random_normal(mean, std, size)  
cdf = cumulative_dist(x, mean, std)
ppf= percent_norm(q, mean, std) 

plt.figure(figsize=(5,5))
plt.plot(x, pdf, "r-")
plt.title("Funcion de densidad de probabilidad")
plt.xlabel("Valor")
plt.ylabel("Densidad")
plt.show()

plt.figure(figsize=(5,5))
plt.plot(x, logpdf, "r-")
plt.title("Logaritmo de la función de densidad de Probabilidad")
plt.xlabel("Valor")
plt.ylabel("Densidad")
plt.show()

plt.figure(figsize=(5,5))
plt.plot(x, cdf, "g-")
plt.title("Función de distribución acumulativa")
plt.xlabel("Valor")
plt.ylabel("Probabilidad")
plt.show()

plt.figure(figsize=(5,5))
plt.plot(x, ppf, "b-")
plt.title("Funcion de distribución acumulativa inversa")
plt.xlabel("Valor")
plt.ylabel("Probabilidad")
plt.show()

# %%
import numpy as np
from scipy.stats import uniform
import matplotlib.pyplot as plt


#1) Probability density function.
def calculate_density_uniform(x, mean=0, std=1): 
    return uniform.pdf(x, loc=mean, scale=std)

#2)Log of the probability density function.
def calculate_log_density_uniform(x, mean=0, std=1): 
    return uniform.logpdf(x, loc=mean, scale=std)       

#3)Random variates.
def generate_random_uniform(mean=0, std=1, size=1): 
    return uniform.rvs(loc=mean, scale=std, size=size, random_state=None)   

#4)Cumulative distribution function.
def cumulative_dist_uniform(x, mean=0, std=1):
    return uniform.cdf(x, loc=mean, scale=std)  

#5)Percent point function (inverse of cdf — percentiles).
def percent_uniform(q, mean=0, std=1):
    return uniform.ppf(q, loc=mean, scale=std)

# %%
from scipy.stats import uniform
import matplotlib.pyplot as plt
import numpy as np


np.random.seed(42)

mean=0 
std=1 
size=1
x = np.arange(-6, 6, 0.15)
q = x

updf = calculate_density_uniform(x, mean, std)
ulogpdf = calculate_log_density_uniform(x, mean, std)
urvs = generate_random_uniform(mean, std, size)  
ucdf = cumulative_dist_uniform(x, mean, std)
uppf= percent_uniform(q, mean, std) 


plt.figure(figsize=(5,5))
plt.plot(x, updf, "r-")
plt.title("Funcion de densidad de probabilidad")
plt.xlabel("Valor")
plt.ylabel("Densidad")
plt.show()

plt.figure(figsize=(5,5))
plt.plot(x, ulogpdf, "r-")
plt.title("Logaritmo de la función de densidad de Probabilidad")
plt.xlabel("Valor")
plt.ylabel("Densidad")
plt.show()

plt.figure(figsize=(5,5))
plt.plot(x, ucdf, "g-")
plt.title("Función de distribución acumulativa")
plt.xlabel("Valor")
plt.ylabel("Probabilidad")
plt.show()

plt.figure(figsize=(5,5))
plt.plot(x, uppf, "b-")
plt.title("Funcion de distribución acumulativa inversa")
plt.xlabel("Valor")
plt.ylabel("Probabilidad")
plt.show()
